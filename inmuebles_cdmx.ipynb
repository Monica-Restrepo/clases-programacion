# %% [markdown]
# <a href="https://colab.research.google.com/github/Monica-Restrepo/clases-programacion/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %% [markdown]
# # **Importando la base de datos**

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
pd.read_csv(url, sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep=';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
# para ver las primeras 5 filas

datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
# para ver las ultimas 5 filas

datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
# quiero ver una muestra aleatoria de la base de datos

datos.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 9072              Departamento             San Ángel             3        0
# 14762                 Cocineta               Condesa             1        0
# 12152             Departamento             Del Valle             1        2
# 23562             Departamento               Condesa             1        0
# 19965             Departamento              Santa Fe             3        1
# 24288             Departamento  Lomas de Chapultepec             4        2
# 2004              Departamento              Santa Fe             2        1
# 17285             Departamento               Condesa             1        0
# 24912  Conjunto Comercial/Sala      Centro Histórico             0        0
# 8579   Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 9072        1   120  19250.0      5215.0    1155.0
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **Exploración inicial de los datos**

# %%
datos.sample(5)
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 19797             Tienda/Salón  Centro Histórico             0        0
# 1002              Departamento          Santa Fe             2        1
# 20568  Conjunto Comercial/Sala  Centro Histórico             0        0
# 13081             Departamento           Condesa             3        0
# 18519             Departamento          Coyoacán             4        2
#
#        Suites  Area    Valor  Condominio  Impuesto
# 19797       0   500   7000.0         NaN    4333.0
# 1002        1    86  10150.0      4574.5     752.5
# 20568       0   245  70000.0     29998.5    5593.0
# 13081       0   110  12250.0      2275.0       NaN
# 18519       1   230  38150.0     11263.0       NaN

# %%
# para conocer el numero de columnas (9) y filas (25121)

datos.shape
# Out:
# (25121, 9)

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
# hace un resumen de todos los datos que contiene la base de datos

datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
# para saber que contine cada Dtype

datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
# puedo cononer dos al tiempo, me muestra en Dataframe

datos[['Habitaciones', 'Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# ##  **Demandas de ML**

# %% [markdown]
# ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
# sacar el promedio en general

datos['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
# pero no esta pidiendo el valor de cada tipo de propiedad, los debemos agrupar por tipo de dato

datos.groupby('Tipo').mean(numeric_only=True)

# el probelma es que saca el promedio de todo, no solo del valor del alquiler
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
datos.groupby('Tipo')['Valor'].mean()

# aca si puedo ver el promedio del valor del alquiler
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
# para ver los valores de menor a mayor

datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
# para hacer mas facil la visualización almacenamos los datos en una variable y así los podemos graficas

df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh', figsize=(10,5), color='skyblue')
# Out:
# <Axes: ylabel='Tipo'>

# %%
# vamos a separar las prpiedades residenciales de las industriales

# primero conocer el nombre de los tipos de propiedad

datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
# crear una lista con los inmuebles comerciales

inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial', 'Terreno Estándar', 'Cochera/Estacionamiento',
       'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial','Hotel', 'Loteo/Condominio','Industria']

# %%
datos.query('@inmuebles_comerciales in Tipo')

# Así visualizo la cantidad de inmuebles comerciales en la base de datos
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
# pero lo que queremos es que los inmuebles comerciales no esten

datos.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = datos.query('@inmuebles_comerciales not in Tipo')
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
# ahora vamos a calcular y graficar el valor promedio de alquiler de las propiedades residenciales

df_tipo_precio = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh', figsize=(10,5), color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
# cuenta cuantos hay de cada tipo

df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
# trae la cantidad en porcentaje

df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
porcentaje_tipo = df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind='bar', figsize=(10,5), color='green', xlabel='Tipo', ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Tipo', ylabel='Porcentaje'>

# %%
# vamos a enfocarnos en los departamentos

df.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.query('Tipo == "Departamento"')
df.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
# corresponde solo a los datos de los departamentos

df.shape
# Out:
# (14764, 9)

# %%
# Guardando el DataFrame en una variable
df_ejemplo = df['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')

# Cambiando el nombre de la columna "Tipo" a "Porcentajes"
df_ejemplo.rename(columns={'Tipo': 'Porcentajes'}, inplace=True)

# Visualizando el DataFrame
df_ejemplo

# se supone que .rename cambia el nombre, pero aca no se ve

# el parámetro inplace=True para que este cambio se aplique definitivamente en nuestro DataFrame df_ejemplo.
# Out:
#               proportion
# Tipo
# Departamento         1.0

# %%
# promedio de habitaciones en los departamentos

df['Habitaciones'].mean()
# Out:
# np.float64(2.5041994039555675)

# %%
# cuantas colonias unicas hay en la base de datos

len(df['Colonia'].unique())
# Out:
# 83

# %%
# otra forma de contar las colonias o barrios

df['Colonia'].nunique()
# Out:
# 83

# %%
# para saber el valor promedio de las colonias, primero se agrupan, luego se usa .mean y después de muestra el resultado en un dataframe

df.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False)
df_colonia = df.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False)
df_colonia
# Out:
#                                   Valor
# Colonia
# Los Alpes                  54250.000000
# Bosques de Aragón          35948.718750
# Coyoacán                   33205.218609
# Roma                       32530.388539
# Lomas de Chapultepec       30232.165189
# ...                                 ...
# El Rodeo                    2275.000000
# Tláhuac                     2275.000000
# San Antonio Tecomitl        2065.000000
# Santa María Aztahuacán      1785.000000
# Potrero de San Bernardino   1190.000000
#
# [83 rows x 1 columns]

# %%
df_colonia.plot(kind='barh', figsize=(15,15), color='orange')
# Out:
# <Axes: ylabel='Colonia'>

# %% [markdown]
# # Verificar la existencia de datos nulos

# %%
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
# valores booleanos True=1 y false=0

df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %% [markdown]
# # Tratar los datos nulos

# %%
# para este caso a los daros nulos se les asignara el valor de 0

df.fillna(0)
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
# vamos a confirmar que todo este con un valor y ya no haya datos nulos

df = df.fillna(0)
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# # **Remover departamentos con valor igual a 0**

# %%
# vamos a verificar valores de alquiler o condominio = 0, | = significa o

df.query('Valor == 0 | Condominio == 0')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
# cada uno de estos registros tiene un indice asociado, primera columna en negrita

df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
# vamos a remover los indices, creando un filtro

df.remover = df.query('Valor == 0 | Condominio == 0').index
# Out:
# <ipython-input-122-56ba42c8d524>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.remover = df.query('Valor == 0 | Condominio == 0').index

# %%
# asi se remueve los indices axis=0 son las filas, inplace es la indicacion para que lo haga en el dataframe

df.drop(df.remover, axis=0, inplace=True)

# %%
# consultemos si si quedo removido y no devuelve ningún valor en 0

df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %%
df.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
# 13  Departamento          Santa Fe             2        1       1    67
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       0.0
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5
# 13   5950.0      2061.5     514.5

# %%
df.Tipo.unique()
# Out:
# array(['Departamento'], dtype=object)

# %%
# como todos son departamentos vamos a quitar la columna Tipo

df.drop('Tipo', axis=1, inplace=True)


# sale error con esta petición abajo se muestra otra solución

# %%
# como todos son departamentos vamos a quitar la columna Tipo
# Check if 'Tipo' column exists before dropping
if 'Tipo' in df.columns:
    df.drop('Tipo', axis=1, inplace=True)
else:
    print("Column 'Tipo' not found in the DataFrame.")
# Out:
# Column 'Tipo' not found in the DataFrame.

# %%
df.sample(5)
# Out:
#                  Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 23932               Roma             1        0       0    38   6300.0
# 3485            Santa Fe             4        3       3   293  42000.0
# 15967  Bosques de Aragón             2        1       2   178  52500.0
# 6564                Roma             3        0       0   146  10500.0
# 19012           Santa Fe             3        1       1    80  10500.0
#
#        Condominio  Impuesto
# 23932      2758.0      84.0
# 3485      14700.0       0.0
# 15967      9800.0    2422.0
# 6564       2975.0       0.0
# 19012      4760.0       0.0

# %% [markdown]
# # Aplicar los filtros solicitados
#
# Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.
#
# Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
seleccion1 = df['Habitaciones'] == 1

# %%
type(seleccion1)
# Out:
# pandas.core.series.Series

# %%
# aplico el filtro creado

df[seleccion1]

# devuelve los apartamentos con una habitación
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
selecion2 = df['Valor'] < 4200
df[selecion2]
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3        Centro Histórico             1        0       0    15  2800.0
# 4               Del Valle             1        0       0    48  2800.0
# 19               Narvarte             1        0       0    48  2625.0
# 37       Centro Histórico             1        0       0    27  2625.0
# 61       Centro Histórico             1        1       0    37  3850.0
# ...                   ...           ...      ...     ...   ...     ...
# 25038  Villa de Guadalupe             2        1       0    50  2800.0
# 25051           Nativitas             2        1       0    62  3500.0
# 25065           Nativitas             2        1       0    50  3150.0
# 25095      Lindavista Sur             2        0       0    63  2800.0
# 25114            Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# ...

# %%
# para verificar que si me separo los del valor <4200

df[selecion2].max()
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 3
# Garages                      2
# Suites                       2
# Area                       176
# Valor                   4025.0
# Condominio            152575.5
# Impuesto                6699.0
# dtype: object

# %%
# apartamentos con 1 habitación y alquiler <4200

filtro1 = df[seleccion1 & selecion2]
filtro1
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
df1 = filtro1

# %%
# apartamentos con 2 dormitorios o mas

filtro2 = (df['Habitaciones'] >= 2) & (df['Valor'] < 10500) & (df['Area'] > 70)
df[filtro2]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %%
df2 = df[filtro2]

# %% [markdown]
# ## **Guardando los archivos**
#
# Almacenar los dataframe(s) completos tras realizar todas las modificaciones

# %%
df.to_csv('Inmuebles_ml.csv')

# %%
pd.read_csv('Inmuebles_ml.csv')

# trae una columna que no se necesita: unnamed, la debemos quitar
#Unnamed = es el indice anterior después de aplicar los filtros
# Out:
#        Unnamed: 0               Colonia  Habitaciones  Garages  Suites  Area  \
# 0               3      Centro Histórico             1        0       0    15
# 1               4             Del Valle             1        0       0    48
# 2               8               Condesa             1        0       1    40
# 3              10               Condesa             4        3       1   243
# 4              13              Santa Fe             2        1       1    67
# ...           ...                   ...           ...      ...     ...   ...
# 14259       25111  Lomas de Chapultepec             3        0       1    80
# 14260       25113              Coyoacán             3        1       2   150
# 14261       25114              Narvarte             1        0       0    28
# 14262       25118               Mixcoac             2        1       0    48
# 14263       25119  Lomas de Chapultepec             2        0       0    70
#
#          Valor  Condominio  Impuesto
# ...

# %%
df.to_csv('inmuebles_ml.csv', index=False)

# %%
pd.read_csv('inmuebles_ml.csv')

# los archivos quedaron huardados con una coma como separador y el archivo inicial esta separado con ; debemos arreglar eso para consistencia de los datos
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2                   Condesa             1        0       1    40   7000.0
# 3                   Condesa             4        3       1   243  45500.0
# 4                  Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 14259  Lomas de Chapultepec             3        0       1    80  10500.0
# 14260              Coyoacán             3        1       2   150  52500.0
# 14261              Narvarte             1        0       0    28   3500.0
# 14262               Mixcoac             2        1       0    48   4900.0
# 14263  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# ...

# %%
df.to_csv('inmuebles_ml.csv', index=False, sep=';')

# %%
df1.to_csv('inmuebles_ml_filtro1.csv', index=False, sep=';')
df2.to_csv('inmuebles_ml_filtro2.csv', index=False, sep=';')

# cuando se abra el cuaderno estos archivos no van a estar, lo ideal es guardarlos en drive

# cuando me permite conectar con drive, copio la ruta donde quedo guardado en pandas y la pego antes de 'inmuebles_...'

# este error al parecer es porque yo non cree este cuaderno, probe con uno que cree 'alumnos' y si me dio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-146-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...
