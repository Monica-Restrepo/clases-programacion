# %% [markdown]
# <a href="https://colab.research.google.com/github/Monica-Restrepo/clases-programacion/blob/main/Alumnos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

datos = pd.read_csv(url, sep=',')

# %%
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
datos.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
datos.tail(5)
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos.shape
# Out:
# (18, 4)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
datos.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %%
# Visualizar los nombres de las columnas
datos.columns

# Verificar los tipos de datos en cada columna
datos.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
df = pd.DataFrame(datos)

# %%
df.isnull()
# Out:
#     Nombre   Edad   Nota  Aprobado
# 0    False  False  False     False
# 1    False  False   True     False
# 2    False  False  False     False
# 3    False  False  False     False
# 4    False  False  False     False
# 5    False  False   True     False
# 6    False  False  False     False
# 7    False  False  False     False
# 8    False  False  False     False
# 9    False  False   True     False
# 10   False  False   True     False
# 11   False  False  False     False
# 12   False  False  False     False
# 13   False  False  False     False
# 14   False  False   True     False
# 15   False  False  False     False
# 16   False  False   True     False
# 17   False  False  False     False

# %%
df.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
datos = datos.fillna(0)

# %%
print(datos.columns)
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
# Guardamos los índices de las filas a eliminar en una variable
alumnos_a_eliminar = datos.query('Nombre == "Alicia" | Nombre == "Carlos"').index

# Eliminamos las filas correspondientes a los estudiantes "Alicia" y "Carlos"
datos.drop(alumnos_a_eliminar, axis=0, inplace=True)

# %%
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
print(datos['Aprobado'].unique())
# Out:
# ['True' 'False' 'Verdadero']

# %%
# Reemplaza 'Verdadero' por 'True'
datos['Aprobado'] = datos['Aprobado'].replace('Verdadero', 'True')

# %%
datos['Aprobado'] = datos['Aprobado'].map({'True': True, 'False': False})

# %%
alumnos_aprobados = datos[datos['Aprobado'] == True]
print(alumnos_aprobados)
# Out:
#       Nombre  Edad  Nota  Aprobado
# 0    Alberto    20   7.5      True
# 4      Brian    21  10.0      True
# 6    Daniela    21   7.0      True
# 12  Stephany    26  10.0      True
# 13    Miriam    25   9.0      True
# 15    Milena    29   7.0      True
# 17     Nadia    34   8.0      True

# %%
# queremos reemplazar los valores 7.0 por 8.0. Para hacerlo, podemos usar el siguiente fragmento de código:

alumnos_aprobados.replace(7.0, 8.0)
# Out:
#       Nombre  Edad  Nota  Aprobado
# 0    Alberto    20   7.5      True
# 4      Brian    21  10.0      True
# 6    Daniela    21   8.0      True
# 12  Stephany    26  10.0      True
# 13    Miriam    25   9.0      True
# 15    Milena    29   8.0      True
# 17     Nadia    34   8.0      True

# %%
# Y para guardar este cambio de forma definitiva, podemos asignarlo a nuestra variable:

alumnos_aprobados = alumnos_aprobados.replace(7.0, 8.0)

# %%
alumnos_aprobados.to_csv('/content/drive/MyDrive/Colab Notebooks/Alumnos.ipynb.alumnos_aprobados.csv', index=False)

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Alumnos.ipynb.alumnos.csv', index=False)

# %%
import pandas as pd

datos = {
    'Nombre': ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Escarabajo'],
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Modelo': [2019, 2003, 1991, 2019, 1990],
    'Kilometraje': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0],
    'Impuesto': [2000.0, 5000.0, 1700.0, 2200.0, 1000.0],
    'Descuento': [380.0, 450.0, 277.0, 400.0, 150.0]
}

df = pd.DataFrame(datos)

# %%
df
# Out:
#        Nombre            Motor  Modelo  Kilometraje     Valor  Impuesto  \
# 0       Jetta  Motor 4.0 Turbo    2019          0.0   88000.0    2000.0
# 1      Passat     Motor Diesel    2003       5712.0  106000.0    5000.0
# 2    Crossfox  Motor Diesel V8    1991      37123.0   72000.0    1700.0
# 3         DS5        Motor 2.0    2019          0.0   89000.0    2200.0
# 4  Escarabajo        Motor 1.6    1990     120000.0   32000.0    1000.0
#
#    Descuento
# 0      380.0
# 1      450.0
# 2      277.0
# 3      400.0
# 4      150.0

# %% [markdown]
# Necesitamos crear una columna llamada "Valor_total" que tenga el valor del automóvil, sumado al impuesto y menos el valor del descuento. ¿Cuál de las siguientes opciones presenta el código correcto para crear esta columna?

# %%
df['valor_total'] = df['Valor'] + df['Impuesto'] - df['Descuento']
df['valor_total']
# Out:
# 0     89620.0
# 1    110550.0
# 2     73423.0
# 3     90800.0
# 4     32850.0
# Name: valor_total, dtype: float64

# %%
df
# Out:
#        Nombre            Motor  Modelo  Kilometraje     Valor  Impuesto  \
# 0       Jetta  Motor 4.0 Turbo    2019          0.0   88000.0    2000.0
# 1      Passat     Motor Diesel    2003       5712.0  106000.0    5000.0
# 2    Crossfox  Motor Diesel V8    1991      37123.0   72000.0    1700.0
# 3         DS5        Motor 2.0    2019          0.0   89000.0    2200.0
# 4  Escarabajo        Motor 1.6    1990     120000.0   32000.0    1000.0
#
#    Descuento  valor_total
# 0      380.0      89620.0
# 1      450.0     110550.0
# 2      277.0      73423.0
# 3      400.0      90800.0
# 4      150.0      32850.0

# %% [markdown]
# Hay varias formas de crear columnas en un DataFrame en Pandas. Algunos ejemplos son:
#
# 1 - Asignación directa de valores a una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = [7, 8, 9]

# %%
df['C']
# Out:
# 0    7
# 1    8
# 2    9
# Name: C, dtype: int64

# %% [markdown]
# 2 - Creación de una columna a partir de operaciones entre otras columnas:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'] + df['B']

# %%
df['C']
# Out:
# 0    5
# 1    7
# 2    9
# Name: C, dtype: int64

# %% [markdown]
# 3 - Uso del método assign() para crear una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df = df.assign(C=[7, 8, 9])

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# 4 - Uso del método apply() para aplicar una función a una columna existente y crear una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'].apply(lambda x: x * 2)

# %%
df['C']
# Out:
# 0    2
# 1    4
# 2    6
# Name: C, dtype: int64

# %% [markdown]
# # para mas información : https://pandas.pydata.org/docs/getting_started/intro_tutorials/05_add_columns.html#how-to-create-new-columns-derived-from-existing-columns

# %% [markdown]
# 1. Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

datos = pd.read_csv(url, sep=',')

# %%
datos.head()
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True

# %%
datos['Puntos_extras'] = datos['Nota'] * 0.4

# %%
datos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extras
# 0  Alberto    20   7.5     True            3.0
# 1      Ana    18   NaN    False            NaN
# 2   Camila    27   2.5    False            1.0
# 3    David    18   5.0    False            2.0
# 4    Brian    21  10.0     True            4.0

# %% [markdown]
# 2. Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.

# %%
datos['Notas_finales'] = datos['Nota'] + datos['Puntos_extras']

# %%
datos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales
# 0  Alberto    20   7.5     True            3.0           10.5
# 1      Ana    18   NaN    False            NaN            NaN
# 2   Camila    27   2.5    False            1.0            3.5
# 3    David    18   5.0    False            2.0            7.0
# 4    Brian    21  10.0     True            4.0           14.0

# %% [markdown]
# 3. Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
#
#
# False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).

# %%
datos['Aprobado_final'] = datos['Notas_finales'].apply(lambda x: True if x >= 7.0 else False)
datos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales  Aprobado_final
# 0  Alberto    20   7.5     True            3.0           10.5            True
# 1      Ana    18   NaN    False            NaN            NaN           False
# 2   Camila    27   2.5    False            1.0            3.5           False
# 3    David    18   5.0    False            2.0            7.0            True
# 4    Brian    21  10.0     True            4.0           14.0            True

# %% [markdown]
# 4. Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.

# %%
datos.query('Aprobado == False & Aprobado_final == True')
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado, Puntos_extras, Notas_finales, Aprobado_final]
# Index: []

# %% [markdown]
# O también se puede hacer de manera más manual:

# %%
seleccion = (datos['Aprobado'] == False) & (datos['Aprobado_final'] == True)
datos[seleccion]
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado, Puntos_extras, Notas_finales, Aprobado_final]
# Index: []

# %%
# tuve que asegurar que los valores fueran verdaderos valores booleanos asi:

datos['Aprobado'] = datos['Aprobado'].astype(str).str.lower() == 'true'
datos['Aprobado_final'] = datos['Aprobado_final'].astype(str).str.lower() == 'true'

# %%
seleccion = (datos['Aprobado'] == False) & (datos['Aprobado_final'] == True)
datos[seleccion]
# Out:
#     Nombre  Edad  Nota  Aprobado  Puntos_extras  Notas_finales  Aprobado_final
# 3    David    18   5.0     False           2.00           7.00            True
# 7   Carlos    19   6.0     False           2.40           8.40            True
# 8   Alicia    35   5.6     False           2.24           7.84            True
# 17   Nadia    34   8.0     False           3.20          11.20            True
